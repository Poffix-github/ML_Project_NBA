# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns
import pandas as pd

# %%
sns.set_theme() # default theme

# %%
games = pd.read_csv('../data/last10g_ELOk32.csv')

# %%
# Create a visualization
sns.relplot(
    data=games,
    x="FG_PCT_avg_10_AWAY", y="HOME_TEAM_WINS",style="HOME_TEAM_WINS",
)
